# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from requests.adapters import HTTPAdapter
from selenium.webdriver.common.by import By

import time
import re
from bs4 import BeautifulSoup 
from tqdm import tqdm 
import requests
from urllib3.util.retry import Retry

# %%
# Launch the browser
driver = webdriver.Chrome()

# Open the desired webpage
driver.get('https://map.naver.com/v5/search/%EC%9D%8C%EC%8B%9D%EC%A0%90?c=15,0,0,0,dh')

# Find the body element
body = driver.find_element('tag name', 'body')

# Scroll down to the bottom of the page
body.send_keys(Keys.END)
time.sleep(2)  # Wait for the page to load

# Scroll up to the top of the page
body.send_keys(Keys.HOME)
time.sleep(2)  # Wait for the page to load

# Get the full page content
full_page_content = driver.page_source

# Close the browser
driver.quit()
# Out:
# <html lang="ko"><head>
#     <title>음식점 검색 - 네이버 지도 - 네이버 지도</title>
#     <meta charset="utf-8">
#     <meta name="Referrer" content="origin">
#     <meta http-equiv="Content-Script-Type" content="text/javascript">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="description" content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결한 새로운 지도를 만나보세요.">
#     <meta name="google-site-verification" content="AO_6MCsaxSfiydw-JSF8cCpFrYPwZDiEo40pMwIwl7Q">
#
#     <meta property="og:type" content="website">
#     <meta property="og:site_name" content="네이버 지도">
#     <meta property="og:title" content="네이버 지도">
#     <meta property="og:image" content="https://map.pstatic.net/res/file/content/global/static/naver/og_map.png">
#     <meta property="og:description" content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결 한 새로운 지도를 만나보세요.">
#     <meta property="twitter:image" content="https://map.pstatic.net/res/file/content/global/static/naver/og_map.png">
#     <meta property="twitter:description" content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결 한 새로운 지도를 만나보세요.">
#     <meta property="twitter:card" content="summary_large_image">
#
#     <!-- base url -->
#     <base href="/v5/">
#     <!-- Configured Head Tags  -->
#     <link rel="apple-touch-icon" sizes="57x57" href="assets/icon/apple-icon-57x57.png">
#     <link rel="apple-touch-icon" sizes="60x60" href="assets/icon/apple-icon-60x60.png">
#     <link rel="apple-touch-icon" sizes="72x72" href="assets/icon/apple-icon-72x72.png">
#     <link rel="apple-touch-icon" sizes="76x76" href="assets/icon/apple-icon-76x76.png">
#     <link rel="apple-touch-icon" sizes="114x114" href="assets/icon/apple-icon-114x114.png">
#     <link rel="apple-touch-icon" sizes="120x120" href="assets/icon/apple-icon-120x120.png">
#     <link rel="apple-touch-icon" sizes="144x144" href="assets/icon/apple-icon-144x144.png">
#     <link rel="apple-touch-icon" sizes="152x152" href="assets/icon/apple-icon-152x152.png">
#     <link rel="apple-touch-icon" sizes="180x180" href="assets/icon/apple-icon-180x180.png">
#     <!--<link rel="icon" type="image/png" sizes="192x192" href="assets/icon/android-icon-192x192.png">-->
#     <link rel="icon" type="image/png" sizes="32x32" href="assets/icon/favicon-32x32.png">
#     <!--<link rel="icon" type="image/png" sizes="96x96" href="assets/icon/favicon-96x96.png">-->
#     <!--<link rel="icon" type="image/png" sizes="16x16" href="assets/icon/favicon-16x16.png">-->
#     <link rel="shortcut icon" type="image/x-icon" href="assets/icon/favicon.ico">
#     <link rel="manifest" href="assets/manifest.json" crossorigin="use-credentials">
#     <link rel="search" type="application/opensearchdescription+xml" href="assets/opensearch.xml" title="네이버지도">
#     <meta name="msapplication-TileColor" content="#00bcd4">
#     <meta name="msapplication-TileImage" content="assets/icon/ms-icon-144x144.png">
#     <meta name="theme-color" content="#00bcd4">
#   <link rel="stylesheet" href="styles.dad40a6cd37536195e16.css"><script charset="utf-8" src="19-es2015.b92719d5e83507595deb.js"></script><script charset="utf-8" src="2-es2015.140648334966ba1213b1.js"></script><script charset="utf-8" src="3-es2015.68f1f2a7e080bfd2520b.js"></script><script charset="utf-8" src="5-es2015.9c5e6921b534ddaa31a7.js"></script><script charset="utf-8" src="common-es2015.69bcf4161ee0405476e9.js"></script><script charset="utf-8" src="29-es2015.8acf434e56bb4d968b73.js"></script><script charset="utf-8" src="1-es2015.dc2bec4daa5420ae7483.js"></script><script charset="utf-8" src="10-es2015.bac1de0321e14695948d.js"></script><script charset="utf-8" src="11-es2015.9a4bc785c63a2e2a3252.js"></script><script charset="utf-8" src="39-es2015.e40aeb9660594bc5ac64.js"></script><script charset="utf-8" src="8-es2015.3485c0b3075955936412.js"></script><style>[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_in, [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_in:hover, [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_out, [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_out:hover{background-image:url(https://ssl.pstatic.net/static/maps/v5/pc/20230404144118/panorama.png);background-size:252px 227px}.retina   [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_in, .retina   [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_in:hover, .retina   [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_out, .retina   [_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .btn_zoom_out:hover{background-image:url(https://ssl.pstatic.net/static/maps/v5/pc/20230404144118/panorama@2x.png)}[_nghost-dls-c65]{position:absolute;left:0;right:0;top:0;bottom:0;height:100%;-ms-user-select:none;-moz-user-select:-moz-none;-webkit-user-select:none;user-select:none}[_nghost-dls-c65]   #sPlugin_popup_base[_ngcontent-dls-c65]{width:0;height:0}[_nghost-dls-c65]   .map_container[_ngcontent-dls-c65]{display:flex;height:100%}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .container[_ngcontent-dls-c65]{position:static}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .container[_ngcontent-dls-c65]   maps-layout[_ngcontent-dls-c65]{z-index:1100}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .container[_ngcontent-dls-c65]   maps-layout[_ngcontent-dls-c65]     .bus-station-popup{display:none}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .container[_ngcontent-dls-c65]   maps-layout[_ngcontent-dls-c65]     map-container{position:absolute;top:0;right:0;bottom:0;left:0}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .container[_ngcontent-dls-c65]   maps-layout[_ngcontent-dls-c65]     map-container .map-container{position:absolute!important;left:0;top:0;right:0;bottom:0;width:100%;height:100%}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .map_box[_ngcontent-dls-c65]{position:static}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   panorama-layout[_ngcontent-dls-c65]{display:flex;z-index:1000}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]   .popup_box[_ngcontent-dls-c65]{display:none}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     .size_control{display:block}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder{bottom:8px;right:8px}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom-widget-holder .list_control{width:29px}[_nghost-dls-c65]   .map_container.panorama[_ngcontent-dls-c65]     control-bottom ...
#   <body class="chrome chrome_113_0_0_0 pc webkit webkit_537_36 macos macos_10_15_7 retina" style="">
#     <app ng-version="11.2.14"><router-outlet></router-outlet><layout _nghost-dls-c65="" class="ng-star-inserted"><div _ngcontent-dls-c65="" id="sPlugin_popup_base"></div><div _ngcontent-dls-c65="" class="u_skip"><a _ngcontent-dls-c65="" href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span _ngcontent-dls-c65="">본문 바로가기</span></a><a _ngcontent-dls-c65="" href="#sidebar" onclick="document.getElementById('sidebar').tabIndex = -1;document.getElementById('sidebar').focus();return false;"><span _ngcontent-dls-c65="">주 메뉴 바로가기</span></a></div><div _ngcontent-dls-c65="" class="map_container fold"><div _ngcontent-dls-c65="" id="sidebar" class="sidebar"><navbar _ngcontent-dls-c65="" _nghost-dls-c35=""><h1 _ngcontent-dls-c35="" class="logo_box"><a _ngcontent-dls-c35="" href="https://www.naver.com" class="link_logo"><span _ngcontent-dls-c35="" class="blind">네이버 지도 </span></a></h1><perfect-scrollbar _ngcontent-dls-c35="" class="scroll_area"><div style="position: static;" class="ps"><div class="ps-content"><div _ngcontent-dls-c35="" class="scroll_box"><ul _ngcontent-dls-c35="" class="list_navbar"><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar home active"><span _ngcontent-dls-c35="" class="navbar_text">지도 홈</span><span _ngcontent-dls-c35="" class="blind ng-star-inserted">선택됨</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar directions"><span _ngcontent-dls-c35="" class="navbar_text">길찾기</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar bus"><span _ngcontent-dls-c35="" class="navbar_text">버스</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar subway"><span _ngcontent-dls-c35="" class="navbar_text">지하철</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar train"><span _ngcontent-dls-c35="" class="navbar_text">기차</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar favorite"><nudge-dot _ngcontent-dls-c35="" key="favorite_navbar" top="14" right="21" _nghost-dls-c32=""><span _ngcontent-dls-c32="" class="badge_dot ng-star-inserted" style="top: 14px; right: 21px;"><span _ngcontent-dls-c32="" class="blind">new</span></span><!----></nudge-dot><span _ngcontent-dls-c35="" class="navbar_text">저장</span><!----></a></li><li _ngcontent-dls-c35="" class="item_navbar"><a _ngcontent-dls-c35="" href="" class="link_navbar settings"><span _ngcontent-dls-c35="" class="navbar_text">더보기</span><!----></a></li></ul></div></div><!----><div class="ps__rail-x" style="left: 0px; bottom: 0px;"><div class="ps__thumb-x" tabindex="0" style="left: 0px; width: 0px;"></div></div><div class="ps__rail-y" style="top: 0px; right: 0px;"><div class="ps__thumb-y" tabindex="0" style="top: 0px; height: 0px;"></div></div></div></perfect-scrollbar><gnb-widget _ngcontent-dls-c35="" _nghost-dls-c34=""><div _ngcontent-dls-c34="" id="gnb" stoppropagation=""></div></gnb-widget></navbar></div><div _ngcontent-dls-c65="" id="container" class="container"><router-outlet _ngcontent-dls-c65=""></router-outlet><shrinkable-layout _nghost-dls-c68="" class="ng-tns-c68-1 ng-trigger ng-trigger-foldPanel ng-trigger-hidePanel ng-star-inserted"><result-panel-folding-button _ngcontent-dls-c68="" _nghost-dls-c67="" class="ng-tns-c68-1 ng-star-inserted" style=""><button _ngcontent-dls-c67="" type="button" class="btn_fold expand"> 접기
# </button></result-panel-folding-button><!----><div _ngcontent-dls-c68="" class="panel_wrap ng-tns-c68-1"><router-outlet _ngcontent-dls-c68="" class="ng-tns-c68-1"></router-outlet><app-base _nghost-dls-c81="" class="ng-star-inserted" style=""><search-input-box _ngcontent-dls-c81="" _nghost-dls-c78=""><div _ngcontent-dls-c78="" class="search_wrap"><div _ngcontent-dls-c78="" class="search_box"><button _ngcontent-dls-c78="" type="button" class="button_search"> 검색 </button><div _ngcontent-dls-c78="" class="input_box"><!----><input _ngcontent-dls-c78="" type="text" autocomplete="off" autofocus="" class="input_search ng-untouched ng-pristine ng-valid" id="input_search1684314749049"></div><button _ngcontent-dls-c78="" type="button" class="button_clear ng-star-inserted" style=""><span _ngcontent-dls-c78="" class="blind">삭제</span></button><!----></div><!----></div></search-input-box><bubble-filter _ngcontent-dls-c81="" class="ng-star-inserted" style="visibility: visible;"><bubble-filter-list _nghost-dls-c79="" class="ng-star-inserted"><div _ngcontent-dls-c79="" class="bubble_filter_area"><ul _ngcontent-dls-c79="" class="bubble_filter_list"><li _ngcontent-dls-c79="" class="bubble_filter_item ng-star-inserted"><button _ngcontent-dls-c79="" type="button" class="bubble_filter ng-star-inserted"><img _ngcontent-dls-c79="" alt="" width="20" height="20" src="https://map.pstatic.net/res/category/image/00024-00032@2x.png">음식점 <!----></button><!----></li><li _ngcontent-dls-c79="" class="bubble_filter_item ng-star-inserted"><button _ngcontent-dls-c79="" type="button" class="bubble_filter ng-star-inserted"><img _ngcontent-dls-c79="" alt="" width="20" height="20" src="https://map.pstatic.net/res/category/image/00024-00012@2x.png">카페 <!----></button><!----></li><li _ngcontent-dls-c79="" class="bubble_filter_item ng-star-inserted"><button _ngcontent-dls-c79="" type="button" class="bubble_filter ng-star-inserted"><img _ngcontent-dls-c79="" alt="" width="20" height="20" src="https://map.pstatic.net/res/category/image/00024-00084@2x.png">펜션 <!----></button><!----></li><!----></ul><div _ngcontent-dls-c79="" class="more_group ng-star-inserted"><button _ngcontent-dls-c79="" type="button" class="btn_more_filter"><span _ngcontent-dls-c79="" class="blind">주변 필터 더보기</span></button><!----></div><!----></div><!----></bubble-filter-list><!----><!----></bubble-filter><!----><router-outlet _ngcontent-dls-c81=""></router-outlet><search-layout _nghost-dls-c141="" class="ng-star-inserted"><!----><h2 _ngcontent-dls-c141="" class="blind ng-star-inserted">검색</h2><div _ngcontent-dls-c141="" class="main -top_space ng-star-inserted"><combined-search-list _ngcontent-dls-c141="" _nghost-dls-c139="" style="visibility: visible;"><!----><salt-search-list _ngcontent-dls-c139="" _nghost-dls-c122="" class="ng-star-inserted" style="visibility: visible;"><correction-info _ngcontent-dls-c122="" _nghost-dls-c112=""><!----></correction-info><nm-external-frame-bridge _ngcontent-dls-c122="" style="height: 100%;"><nm-iframe _nghost-dls-c113="" class="ng-star-inserted" style="height: 100%; pointer-events: auto;"><iframe _ngcontent-dls-c113="" src="about:blank" id="searchIframe" title="검색어 '음식점'에 대한 결과"></iframe></nm-iframe><!----><!----><!----></nm-external-frame-bridge><!----></salt-search-list><!----><!----><!----><!----></combined-search-list></div><div _ngcontent-dls-c141="" class="sub ng-star-inserted hidden"><router-outlet _ngcontent-dls-c141=""></router-outlet><!----></div><!----><!----></search-layout><!----></app-base><!----><!----></div><!----></shrinkable-layout><!----><div _ngcontent-dls-c65="" class="map_box"><maps-controller _ngcontent-dls-c65="" _nghost-dls-c46="" class="ng-star-inserted"><!----></maps-controller><!----><!----></div><div _ngcontent-dls-c65="" class="bottom"></div></div><!----></div><!----><message _ngcontent-dls-c65="" _nghost-dls-c36="" class="ng-tns-c36-0 ng-trigger ng-trigger-messageTransition ng-star-inserted" style="transform: translate(-50%, 100%); displa ...
#     <div id="preview_area">
#       <div class="navbar_box">
#         <h1 class="logo_box">
#           <span class="link_logo">
#             <span class="blind">NAVER</span>
#           </span>
#         </h1>
#         <div class="scroll_area">
#           <div class="scroll_box">
#             <ul class="list_navbar">
#               <li class="item_navbar">
#                 <span class="link_navbar home">
#                   <span class="navbar_text">지도 홈</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar directions">
#                   <span class="navbar_text">길찾기</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar bus">
#                   <span class="navbar_text">버스</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar subway">
#                   <span class="navbar_text">지하철</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar train">
#                   <span class="navbar_text">기차</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar favorite">
#                   <span class="navbar_text">저장</span>
#                 </span>
#               </li>
#               <li class="item_navbar">
#                 <span class="link_navbar settings">
#                   <span class="navbar_text">더보기</span>
#                 </span>
#               </li>
#             </ul>
#           </div>
#         </div>
#       </div>
#       <div class="loading_box"></div>
#     </div>
#     <div id="baseMap" class="base_map mapboxgl-map" tabindex="0" style="position: relative; overflow: hidden; background: url(&quot;data:image/png;base64,...&quot;) 0px 0px repeat transparent;"><div style="position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; overflow: visible; width: 100%; height: 100%; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); z-index: 0; cursor: url(&quot;https://ssl.pstatic.net/static/maps/mantle/2x/openhand.cur&quot;), default;"><div class="mapboxgl-map" style="position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; overflow: visible; width: 100%; height: 100%; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); z-index: 0;"><div style="position: absolute; display: none; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; overflow: visible; width: 100%; height: 100%; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); background-color: rgb(255, 255, 255); z-index: 10000; opacity: 0.5;"></div><div class="mapboxgl-canary" style="visibility: hidden;"></div><div class="mapboxgl-canvas-container mapboxgl-interactive mapboxgl-touch-drag-pan mapboxgl-touch-zoom-rotate" style="position: absolute; z-index: 100;"><canvas class="mapboxgl-canvas" tabindex="0" aria-label="Map" role="region" width="2276" height="1414" style="width: 1138px; height: 707px;"></canvas></div><div class="mapboxgl-control-container"><div class="mapboxgl-ctrl-top-left"></div><div class="mapboxgl-ctrl-top-right"></div><div class="mapboxgl-ctrl-bottom-left"><div class="mapboxgl-ctrl" style="display: none;"><a class="mapboxgl-ctrl-logo" target="_blank" rel="noopener nofollow" href="https://www.mapbox.com/" aria-label="Mapbox logo"></a></div></div><div class="mapboxgl-ctrl-bottom-right"></div></div><div class="mapboxgl-canvas-container mapboxgl-interactive" style="position: relative; z-index: 10; visibility: hidden;"><canvas class="mapboxgl-canvas" tabindex="0" aria-label="Map" role="region" width="2276" height="1414" style="width: 1138px; height: 707px; z-index: 0; display: block;"></canvas><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 1;"><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: none; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 0; user-select: none;"></div><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 1; user-select: none;"></div><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 100;"><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 101;"></div><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 103;"></div><div style="overflow: visible; width: 100%; height: 0px; position: absolute; display: block; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 106;"></div></div></div></div></div></div><div style="position: absolute; z-index: 100; margin: 0px; padding: 0px; pointer-events: none; right: 0px; bottom: 0px;"><div style="border: 0px none; margin: 0px; padding: 0px; pointer-events: none;"><div style="position: relative; z-index: 1; padding: 1px 5px; height: 16px; line-height: normal; font-family: &quot;Apple SD Gothic Neo&quot;, &quot;Apple SD Gothic&quot;, sans-serif; border-radius: 2px 0px 0px; background: rgba(255, 255, 255, 0.5); user-select: none; box-sizing: content-box !important; pointer-events: auto;"><div style="font-size: 0px; padding: 2px; float: righ ...
#     <div id="subwayMap"></div>
#     <div id="_unsupported_browser"></div>
#     <noscript>
#       <div id="no-script">
#         <div class="no-script-message">
#           <div class="title">네이버 지도를 사용하려면 자바스크립트 설정이 필요합니다.</div>
#           <div class="desc">
#             Chrome, Firefox 와 같은 브라우저에서 자바스크립트 기능을 사용 설정하지 않으면 네이버 지도를 볼 수 없습니다.
#           </div>
#           <div class="explain">[예시 : Chrome 브라우저 설정 방법]</div>
#           <ol class="items">
#             <li>Chrome 브라우저 창을 열고, 환경설정을 클릭</li>
#             <li>하단에서 고급 선택</li>
#             <li>‘개인정보 및 보안’ 에서 콘텐츠 설정을 클릭</li>
#             <li>자바스크립트 클릭 후, 허용으로 설정</li>
#           </ol>
#         </div>
#       </div>
#     </noscript>
#     <script>
#       var ie = (function () {
#         if (window.ActiveXObject === undefined) return null;
#         if (!document.querySelector) return 7;
#         if (!document.addEventListener) return 8;
#         if (!window.atob) return 9;
#         if (!document.__proto__) return 10;
#         return 11;
#       })();
#       if (ie && ie < 11) {
#         location.href = 'https://map.naver.com/v5/unsupported-browser.html';
#       }
#       __Zone_disable_requestAnimationFrame = true;
#       __Zone_disable_on_property = true;
#       __Zone_disable_timers = true;
#       __Zone_disable_XHR = true;
#       __Zone_disable_PromiseRejectionEvent = true;
#       __Zone_disable_crypto = true;
#       __zone_symbol__BLACK_LISTED_EVENTS = [
#         'pointerstart',
#         'pointermove',
#         'pointerend',
#         'pointerout',
#         'pointerover',
#         'mousemove',
#         'mousewheel',
#         'wheel'
#       ];
#       window['__zone_symbol__PASSIVE_EVENTS'] = [
#         'scroll',
#         'message',
#         'mouseout',
#       ];
#       var targets = [window, Worker, Document, HTMLBodyElement, HTMLCanvasElement, HTMLElement];
#       __Zone_ignore_on_properties = [];
#       targets.forEach(function (target) {
#         __Zone_ignore_on_properties.push({
#           target: target,
#           ignoreProperties: [
#             'scroll',
#             'message',
#             'pointermove',
#             'mousemove',
#             'mousewheel',
#             'mouseout',
#             'wheel',
#             'mousewheel'
#           ]
#         });
#       });
#       if (ie) {
#         window.__Zone_enable_cross_context_check = true;
#       }
#     </script>
#   <script src="runtime-es2015.d0b12ecf5949ab600158.js" type="module"></script><script src="runtime-es5.d0b12ecf5949ab600158.js" nomodule="" defer=""></script><script src="polyfills-es5.674f2ed47e6fc1107d40.js" nomodule="" defer=""></script><script src="polyfills-es2015.539da1e07b18ba53054e.js" type="module"></script><script src="scripts.a914ed42010ea07f4620.js" defer=""></script><script src="vendor-es2015.94e950de918941577601.js" type="module"></script><script src="vendor-es5.94e950de918941577601.js" nomodule="" defer=""></script><script src="main-es2015.3be90f24d57a65896b1c.js" type="module"></script><script src="main-es5.3be90f24d57a65896b1c.js" nomodule="" defer=""></script>
#
# <script src="https://ssl.pstatic.net/sstatic.map/openapi/maps3.js?time=1682559249060" async="" type="text/javascript"></script><script src="https://ssl.pstatic.net/sstatic.map/openapi/maps3-gl.js?time=1682559249060" async="" type="text/javascript"></script></body></html>
